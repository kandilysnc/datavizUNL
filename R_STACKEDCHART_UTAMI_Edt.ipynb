# %%
library(dplyr)
library(ggplot2)
library(zoo)
library(lubridate)
library("RColorBrewer")
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Attaching package: ‘lubridate’
#
# The following object is masked from ‘package:base’:
#
#     date

# %% [markdown]
# **Import library: dplyr, tidyr, ggpplot2, zoo, lubridate and "RColorBrewer"**
#
#
# a. dplyr --- to use the function mutate (), select (), filter (), summarise () or arrange (), to join also two datasets to find out the percentage of certain field compared to total volume of the dataset
#
# b. ggplot2 -- to call out the plot
#
# c. zoo -- to use yearmon function
#
# d. lubridate -- to change date data by using floor_date function, cleandate function which is followed by POSIXct (calender time), POSIXit(dmyhms version)
#
# e. RColorBrewer -- to change color in plots using scale_fill_brewer(palette="X") function

# %%
unlcrimes <- read.csv("Data/unlcrime-4.csv")

# %% [markdown]
# call out the data

# %%
head (unlcrimes)
# Out:
#   CaseNo   Incident.Code                 Reported            Case.Status
# 1 11000001 NARCOTICS - POSSESSION        2011-01-01T00:10:00 Cleared by Arrest
# 2 11000011 NARCOTICS - POSSESSION        2011-01-01T23:16:00 Cleared by Arrest
# 3 11000013 ALCOHOL - MINOR IN POSSESSION 2011-01-02T00:38:00 Cleared by Arrest
# 4 11000019 TRAFFIC - SUSPENDED DRIVER    2011-01-02T23:24:00 Cleared by Arrest
# 5 11000020 NARCOTICS - POSSESSION        2011-01-03T04:46:00 Cleared by Arrest
# 6 11000022 MEDICAL EMERGENCY             2011-01-03T10:34:00 Inactive
#   Start.Occurred      End.Occurred Building
# 1 2011-01-01T00:10:00              515 N 19th Parking Lot Vine to
# 2 2011-01-01T23:16:00
# 3 2011-01-02T00:38:00
# 4 2011-01-02T23:24:00
# 5 2011-01-03T04:46:00
# 6 2011-01-03T10:34:00              Campus Recreation Center
#   Location                                     Stolen Damaged
# 1 515 North 19th St. (GOV'T PARKING LOT (UNL)) NA     NA
# 2 N 10TH ST & CHARLESTON ST (STREET)           NA     NA
# 3 N 17TH ST & N ANTELOPE VALLEY PKWY (STREET)  NA     NA
# 4 N 17TH ST & VINE ST (STREET)                 NA     NA
# 5 N 10TH ST & CHARLESTON ST (STREET)           NA     NA
# 6 841 North 14th St (SPORT FACILITIES)         NA     NA
#   Description
# 1 UNL student cited and released for Poss of Marijuana < 1 oz and Poss of Drug Paraphernalia after a CSO reported suspicious drug-related activity from a vehicle.  1.2 g of marijuana seized.
# 2 Traffic Stop.  Vehicle stopped for a headlight out.  Upon contact Officer smelled the strong odor of burnt marijuana.  Driver cited/released for Possession of Drug Paraphernalia after a search yielded a pipe with burnt marijuana residue.
# 3 Three persons cited for MIPC after being stopped for no headlights at N. Antelope valley parkway and N. 17rh Street.
# 4 Non-student cited and lodged in jail for Driving Under Suspension after being stopped for speeding.
# 5 Non-student stopped for speeding.  Officer smelled burnt marijuana from within the vehicle and upon searching located burnt marijuana cigarettes, a pipe, and .6 g of marijuana.  Cited and released for Speeding, Poss of Marijuana < 1 oz, and Poss of Drug Paraphernalia.
# 6 UNL affiliated female disoriented in need of medical attention at the Rec Center. Transported to the hospital by LFR.

# %% [markdown]
# Look at the overal dataset in R

# %%
unlcrimes %>% mutate(
# 27    Husker Hall
# 28    Campus Recreation Center
# 29    Abel Hall
# 30    Selleck Quad 4000
# ⋮     ⋮
# 11548 Business Administration Building
# 11549
# 11550
# 11551
# 11552
# 11553
# 11554 University Suites
# 11555
# 11556
# 11557 Nebraska Champions Club
# 11558
# 11559
# 11560 Beadle Center
# 11561
# 11562
# 11563
# 11564
# 11565
# 11566
# 11567
# 11568 Pound Hall
# 11569 The 50-50
# 11570 The Village
# 11571 Morrill Hall
# 11572
# 11573 Burr Hall
# 11574
# 11575 Nebraska Hall
# 11576 Phi Gamma Delta
# 11577
#       Location                                                   Stolen Damaged
# 1     515 North 19th St. (GOV'T PARKING LOT (UNL))                NA     NA
# 2     N 10TH ST & CHARLESTON ST (STREET)                          NA     NA
# 3     N 17TH ST & N ANTELOPE VALLEY PKWY (STREET)                 NA     NA
# 4     N 17TH ST & VINE ST (STREET)                                NA     NA
# 5     N 10TH ST & CHARLESTON ST (STREET)                          NA     NA
# 6     841 North 14th St (SPORT FACILITIES)                        NA     NA
# 7     Cyberspace/Internet (INTERNET/CYBERSPACE)                   NA     NA
# 8     740 Stadium Dr. (SPORT FACILITIES)                          NA     NA
# 9     1600 North 33rd St (GOV'T PARKING LOT (UNL))               400    500
# 10    1220 T St (UNL ACADEMIC BUILDING)                           NA     NA
# 11     (GOV'T PARKING LOT (UNL))                                  NA     NA
# 12    660 North 12th St (UNL ACADEMIC BUILDING)                   NA     NA
# 13     (INTERNET/CYBERSPACE)                                      NA     NA
# 14    2244 Vine Street (UNL APARTMENT)                            NA     15
# 15    3201 W Street (SIDEWALK)                                   300     NA
# 16    1248 R (LIBRARY)                                            NA     NA
# 17    301 North 12th St (UNL SUPPORT FACILITY (office, service))  NA    350
# 18    N 17TH ST & R ST (STREET)                                   NA     NA
# 19    1104 R St (UNL ACADEMIC BUILDING)                           50     NA
# 20    1600 Court St (SPORT FACILITIES)                            NA     NA
# 21    1525 South 19th #5 (DUPLEX -  off campus)                   NA     NA
# 22    X ST & N 16TH ST (STREET)                                   NA     NA
# 23    440 N 17th Street (UNL RESIDENCE HALL)                      NA     NA
# 24    440 N 17th Street (UNL RESIDENCE HALL)                      NA     NA
# 25    3975 Potter St (GOV'T PARKING LOT (UNL))                    NA    800
# 26    513 North 17th St (SIDEWALK)                                NA    100
# 27    705 North 23rd St (GOV'T PARKING LOT (UNL))                780     50
# 28    841 North 14th St (SPORT FACILITIES)                        43     NA
# 29    880 North 17th St (UNL RESIDENCE HALL)                      NA     NA
# 30    600 North 15th St. (UNL RESIDENCE HALL)                     NA     NA
# ⋮     ⋮                                                          ⋮      ⋮
# 11548 512 North 12th St (GOV'T PARKING LOT (UNL))                0      100
# 11549 440 N 17th Street (GOV'T PARKING LOT (UNL))                0      550
# 11550 N 17TH ST & Q ST (GAS/SERVICE STATION)                     0        0
# 11551 N ANTELOPE VALLEY PKWY & Salt Creek RDWY (STREET)          0        0
# 11552 N 17TH ST & Q ST (STREET)                                  0        0
# 11553 N ANTELOPE VALLEY PKWY & Salt Creek RDWY (STREET)          0        0
# 15    Non UNL affiliated person had $300.00 stolen. This occurred off campus and was tunred over to LPD.
# 16    Transient taken to detox after he passed out in Love Library (PBT refused). He was issued a Ban and Bar Letter.
# 17    Wind blew a dumpster into a vehicle owned by UNL ($350 damage).
# 18    UNL student stopped for expired license plates and found to have consumed alcohol.  Ultimately tested under legal limit.  Taken to Detox and cited for Reckless Driving.  .072 BAC
# 19    Black and green Gary Fischer bicycle stolen sometime in September 2010.
# 20    Non UNL affiliated male suffered a seizure while attending a basketball game.
# 21    UNL student reported being concerned about the behavior of an ex-boyfriend.
# 22    4 female UNL students contacted after a traffic infraction. 1 cited for DUI, 3 cited for MIPC, open container and false information. BAC. for driver .181.
# 23    CSO reported possible alcohol activity.  Four UNL students cited and released for MIP after alcohol was observed in the room.  .089, .049, .055, & .176 BAC's
# 24    Marijuana pipe found under a couch cushion in the room while new residents were moving in.
# 25    UNL owned snow blower struck a parked vehicle.
# 26    UNL snow plow struck a meter while clearing the sidewalk of snow causing it to slide into a parked vehicle.  Damage to City of Lincoln meter (Bent over) and parked vehicle (Driver's side mirror).
# 27    Belated report of a laptop computer and Sony digital recorder stolen from vehicle.  Pry marks found on passenger side door frame.  Occurred between December 15th, 2010 to January 7th, 2011.
# 28    Black bi-fold wallet and contents taken from an unsecured locker in the men's locker room.  Debit/Credit cards were canceled by victim.
# 29    Person cited for Possession of Marijuana less than an ounce, this occured in Abel Hall.
# 30    Safe found unlocked in Selleck Quad, contents inventoried and safe locked.
# ⋮     ⋮
# 11548 Two vehicle non injury accident involving a UNL vehicle, dock of Love Library.
# 11549 A Nebraska student reported they had hit a sign with their vehicle.
# 11550 Student contacted at 17th and Q Street, found to be under the influence of drugs. Cited for DUI-D and Refusing a Chemical Test.
# 11551 Vehicle stopped at 21st and SCR, driver found to be suspend. Driver cited for DUS and Improper turn and released.
# 11552 Vehicle stopped for no plates or paper. Marijuana was found in the vehicle. Driver cited for Possession of Marijuana and Possession of Drug Paraphernalia.
# 11553 A vehicle was stopped for a traffic violation. A non-affiliate was cited/lodged for DUS and cited for Failure to signal turn.
# 11554 A student and a non-affiliate were contacted in a vehicle due to suspicious activity. Both were cited/released for MIP and the student was also cited/released for Possession of Marijuana < 1 oz.
# 11555 A report of a working fire set intentionally by an unknown person. Investigation continues.
# 11556 Officer identified driver to be suspended using MDT. Driver was cited/lodged for Possession of a Controlled Substance. Cited/released for Possession of Substance, DUS, Open Container, Possession of Marijuana < 1oz. and Possession of Drug Paraphernalia. Passenger cited/lodged for Possession of a Controlled Substance. Cited/released for Possession of Marijuana < 1 oz and Possession of Drug Paraphernalia. Both are non-affiliates.
# 11557 The inner pan of a trash receptacle was found to be damaged.
# 11558 University of Nebraska reported a server breach, case turned over to FBI.
# 11559 Non-affiliate was lodged in jail for Driving Under Suspension and cited for narcotic offenses.
# 11560 University affiliate was lodged in jail for 3rd Degree Domestic Assault.
# 11561 Non affiliate contacted and taken to The Bridge (.214 BAC).
# 11562 A non-affiliate was contacted due to suspended driving privileges. The driver was cited/released for DUS.
# 11563 Non university affiliate was cited for DUI <.15 (.105 BAC) and lodged for Criminal Impersonation.
# 11564 Non university affiliate cited/released for No Valid Registration and for Driving Under Suspension.
# 11565 Non university affiliate cited/released for Headlight Violation, Possession of Paraphernalia, and Possession of Marijuana <1oz.
# 11566 Non-university affiliate was contacted on a traffic stop and cited for DUI < .15 and no headlights after dark. (.084BAC)
# 11567 Non-university affiliate contacted on a traffic stop and cited for DUS. Passenger was lodged on two active warrants.
# 11568 Contacted student in their room at Pound Hall where Marijuana, Alcoholic and a Fake ID where found. Student cited for Possession of Marijuana < 1oz, Minor in Possession, Possession of a Fake ID Card and Possession o Drug Paraphernalia.
# 11569 A report of a check welfare made to UPD in reference to a resident of the 50/50. Attempts to locate the person have been unsuccessful. Investigation is on-going.
# 11570 A Nebraska student reported a disturbance occurring at their university apartment. A non-affiliate was causing a disturbance outside of the residence and refusing to leave. Investigation continues
# 11571 Water pipe broke in Morrill Hall causing minor damage.
# 11572 A non-affiliate was contacted on a traffic stop for negligent driving. The driver was cited/released for DUI > .15 (.192 BrAC), Negligent Driving and No Operator's License.
# 11573 A non-affiliate was contacted on a check welfare assist for LFR. The non-affiliate was cited/lodged for Assault with Bodily Fluids on a Peace Officer (spit) and cited/released for Trespassing 1st Degree.
# 11574 3 non-affiliates were contacted on a traffic stop. The driver was cited/lodged for Possession of a Deadly Weapon by a Prohibited Person and cited/released for Carrying a Concealed Weapon. A passenger was also lodged on an outstanding warrant.
# 11575 A non-affiliate was cited/released for DUS on a police contact.
# 11576 Two University students were cited/released for Trespassing.  One student was also cited for Possession of a False ID.
# 11577 A UNL student was contacted on a traffic stop ad cited/released for MIP.  Additionally, a non-affiliate occupant was cited/released for Possession of Marijuana (12.2 g) < 1 Ounce, Open Alcohol Container, and Speeding (6-10).
#       CleanDate
# 1     2011-01-01 00:10:00
# 2     2011-01-01 23:16:00
# 3     2011-01-02 00:38:00
# 4     2011-01-02 23:24:00
# 5     2011-01-03 04:46:00
# 6     2011-01-03 10:34:00
# 7     2011-01-03 14:25:00
# 8     2011-01-03 20:51:00
# 9     2011-01-04 10:57:00
# 10    2011-01-04 16:40:00
# 11    2011-01-04 17:18:00
# 12    2011-01-04 21:43:00
# 13    2011-01-06 08:43:00
# 14    2011-01-06 17:18:00
# 15    2011-01-06 17:44:00
# 16    2011-01-07 10:00:00
# 17    2011-01-07 14:17:00
# 18    2011-01-08 02:50:00
# 19    2011-01-08 10:40:00
# 20    2011-01-08 14:46:00
# 21    2011-01-08 19:35:00
# 22    2011-01-09 02:21:00
# 23    2011-01-09 03:05:00
# 24    2011-01-09 10:20:00
# 25    2011-01-10 08:37:00
# 26    2011-01-10 11:10:00
# 27    2011-01-10 14:47:00
# 28    2011-01-10 16:43:00
# 29    2011-01-10 23:24:00
# 30    2011-01-11 00:53:00
# ⋮     ⋮
# 11548 2016-12-19 14:04:00
# 11549 2016-12-19 21:53:00
# 11550 2016-12-20 16:03:00
# 11551 2016-12-20 20:09:00
# 11552 2016-12-21 16:34:00
# 11553 2016-12-21 19:14:00
# 11554 2016-12-21 20:37:00
# 11555 2016-12-21 22:02:00
# 11556 2016-12-22 01:38:00
# 11557 2016-12-22 05:35:00
# 11558 2016-12-22 07:19:00
# 11559 2016-12-22 22:52:00
# 11560 2016-12-23 00:28:00
# 11561 2016-12-23 01:46:00
# 11562 2016-12-23 18:34:00
# 11563 2016-12-23 22:25:00
# 11564 2016-12-23 23:06:00
# 11565 2016-12-23 23:54:00
# 11566 2016-12-24 01:44:00
# 11567 2016-12-24 14:03:00
# 11568 2016-12-26 14:34:00
# 11569 2016-12-27 21:26:00
# 11570 2016-12-27 23:40:00
# 11571 2016-12-28 13:27:00
# 11572 2016-12-29 03:16:00
# 11573 2016-12-29 19:09:00
# 11574 2016-12-30 15:14:00
# 11575 2016-12-30 19:54:00
# 11576 2016-12-30 22:15:00
# 11577 2016-12-31 23:04:00

# %% [markdown]
# Clean the data since it contains irregular form of data: 2011-01-01T00:10:00. We already imported the lubridate, now we can use: as.POSIXct(Reported, format="%Y-%m-%dT%H:%M")

# %%
unlcrimesbymonth <- unlcrimes %>% mutate(
    shortdate = format(as.POSIXct(Reported, format="%Y-%m-%d")),
    month = floor_date(ymd(shortdate), "month"),
    sortedincident=ifelse(Incident.Code == "NARCOTICS - POSSESSION"| Incident.Code == "ALCOHOL - MINOR IN POSSESSION", "Possession", "Other"),
) %>% group_by(sortedincident, month) %>% summarize(
    count = n()
    )
head(unlcrimesbymonth)
# Out:
#   sortedincident month      count
# 1 Other          2011-01-01 117
# 2 Other          2011-02-01 142
# 3 Other          2011-03-01 131
# 4 Other          2011-04-01 138
# 5 Other          2011-05-01 119
# 6 Other          2011-06-01 120

# %% [markdown]
# since we want to figure out the data per month, then we need to do:
# 1. use the format (as.POSIXct(Reported, format ="%Y-%m-%d"))
# 2. use the floor_date function to call out only the month. first create a field name: month and populate it with the floor date of the formatted Date column in "%Y -%m - %d" but slicing it by month only.
#
# * Next, because we want to choose only two reported crimes: narcotics - possesion and alcohol - minor in possession in all the UNLPD reported crimes, then we can use the ifelse function
#
# as in:
#
# category = ifelse (This == "That" | This == "Them", "Whatever you want")
#            ifelse (Other == "Thing" | Other == "Foo", "The Other Thing you want", "The options when neither of these things are true")
#
# * so we fill it with:
#
# sortedincident = ifelse (Incident.Code == "NARCOTICS - POSSESSION" | Incident. Code == "ALCOHOL - MINOR IN POSSESSION", "Possession", "Other"),
#
#
# * after that we group by and calling the name of variable in the ifelse function as follow:
#
# %>% group_by (sortedincident, month) %>% summarize
#
#
# * and count it!
#
# Last, call out the dataset!

# %%
sapply(unlcrimesbymonth, class)
# Out:
# sortedincident          month          count
#    "character"         "Date"      "integer"

# %% [markdown]
# ggplot(unlcrimesbymonth, aes(x=month, y=count, fill=sortedincident)) + geom_area()+ scale_fill_brewer(palette="Spectral") +
#   labs(x="month", y="count", title="UNLPD reported crimes from 2012 to 2017", subtitle="Possesion cases including narcotics and alcohol minor relatively low in the beginning of Fall semester.", caption="By Utami") +
# theme(plot.title = element_text(size = 16, face = "bold"), axis.title = element_text(size = 8), axis.ticks=element_blank())

# %% [markdown]
# **Call out the ggplot and do some minor revision as follow:**
# **1. ggplot(unlcrimesbymonth, aes(x=month, y=count, fill=sortedincident)) + geom_area()+ scale_fill_brewer(palette="Spectral")**
#
# note:
# * ggplot to call out the plot
# * aes to write the title in x and y axis, x=month and y=count, fill (title of the legend) = sorted incident
# * geom_area () to call out the area plot
#
# **2. Rewrite the title, subtitle, write the byline, as follow:**
#
# labs(x="month", y="count", title="UNLPD reported crimes from 2012 to 2017", subtitle="Possesion cases including narcotics and alcohol minor relatively low in the beginning of Fall semester.", caption="By Utami")
#
# **3. Revise the size of the title and subtitle as well as erasing the annoying ticks on the plot, as follow:**
#
# theme(plot.title = element_text(size = 16, face = "bold"), axis.title = element_text(size = 8), axis.ticks=element_blank())

# %% [markdown]
# **POSSESSION CASES COMPARED TO UNLPD TOTAL REPORTED CRIMES FROM 2012 TO 2017**

# %%
monthtotals <- unlcrimes %>% mutate(
    shortdate = format(as.POSIXct(Reported, format="%Y-%m-%d")),
    month = floor_date(ymd(shortdate), "month"),
    sortedincident=ifelse(Incident.Code == "NARCOTICS - POSSESSION"| Incident.Code == "ALCOHOL - MINOR IN POSSESSION", "Possession", "Other"),
) %>% group_by(month) %>% summarize(
    count = n()
    )
percents <- unlcrimesbymonth %>% 
    inner_join(monthtotals, by="month") %>%
    mutate(percentage = (count.x/count.y)*100)

# %% [markdown]
# To find the percentage of possession cases compared to the UNLPD total reported crimes from 2012 to 2017, we need to do some steps:
#
# **1. merge two data sets by creating a field called monthtotals and use mutate fuction**
#
# Use the same function with the individual cases volume, which is:
# shortdate = format(as.POSIXct(Reported, format="%Y-%m-%d")),
#     month = floor_date(ymd(shortdate), "month"),
#     sortedincident=ifelse(Incident.Code == "NARCOTICS - POSSESSION"| Incident.Code == "ALCOHOL - MINOR IN POSSESSION", "Possession", "Other"),
# ) %>% group_by(month) %>% summarize(
#     count = n()
#     )
#
# **2. calculate the percentage and joining the datasets**
#
# percents <- unlcrimesbymonth %>%
#     inner_join(monthtotals, by="month") %>%
#     mutate(percentage = (count.x/count.y)*100)

# %%
ggplot(percents, aes(x=month, y=percentage, fill=sortedincident)) +
    geom_area() + scale_fill_discrete(name="Type of crimes") + 
    scale_fill_brewer(palette="PRGn") +
    labs(x="month", y="Total cases", title="UNLPD reported crimes from 2012 to 2017", subtitle="Possesion cases including narcotics and alcohol minor relatively low in the beginning of Fall semester.", caption="By Utami")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
# plot without title

# %% [markdown]
# Call out the area plot and do some revision in title, subtitle, byline

# %%
ggplot(percents, aes(x=month, y=percentage, fill=sortedincident)) +
    geom_area() + scale_fill_discrete(name="Type of crimes") + 
    scale_fill_brewer(palette="PRGn") +
    labs(x="month", y="Total cases", title="UNLPD reported crimes from 2012 to 2017", subtitle="Possesion cases including narcotics and alcohol minor relatively low in the beginning of Fall semester.", caption="By Utami") +
    theme(plot.title = element_text(size = 16, face = "bold"), axis.title = element_text(size = 8), axis.ticks=element_blank())
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
# plot without title

# %% [markdown]
# **Adding little detail that matter:**
# 1. erasing ticks
# 2. resizing fonts
# 3. resizing x and y axis
# 4. editing title, subtitle
