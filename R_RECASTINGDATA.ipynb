# %%
library(reshape2)

# %% [markdown]
# use reshape 2 refers to an R package used for transform data to wide and long data. Hadley Wickham, a Chief Scientist at RStudio, and an Adjunct Professor of Statistics at the University of Auckland, Stanford University, and Rice University created this reshape 2 for R.

# %%
population <- read.csv("Data/population-4.csv")

# %% [markdown]
# import the population data

# %%
head (population)
# Out:
#   STNAME  CTYNAME        POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2012
# 1 Alabama Autauga County  54742           55255           55027
# 2 Alabama Baldwin County 183199          186653          190403
# 3 Alabama Barbour County  27348           27326           27132
# 4 Alabama Bibb County     22861           22736           22645
# 5 Alabama Blount County   57376           57707           57772
# 6 Alabama Bullock County  10892           10722           10654
#   POPESTIMATE2013 POPESTIMATE2014 POPESTIMATE2015 POPESTIMATE2016
# 1  54792           54977           55035           55416
# 2 195147          199745          203690          208563
# 3  26938           26763           26270           25965
# 4  22501           22511           22561           22643
# 5  57746           57621           57676           57704
# 6  10576           10712           10455           10362

# %% [markdown]
# find out the form and headers of the dataset

# %%
longpopulation <- melt(population)
head(longpopulation)
# Out:
# Using STNAME, CTYNAME as id variables
#   STNAME  CTYNAME        variable        value
# 1 Alabama Autauga County POPESTIMATE2010  54742
# 2 Alabama Baldwin County POPESTIMATE2010 183199
# 3 Alabama Barbour County POPESTIMATE2010  27348
# 4 Alabama Bibb County    POPESTIMATE2010  22861
# 5 Alabama Blount County  POPESTIMATE2010  57376
# 6 Alabama Bullock County POPESTIMATE2010  10892

# %% [markdown]
# So, we want to use the long format data which consists of a column of "variable" and a column of "values" of the variable. In this data, the variable is POPESTIMATE2010 and the value is the estimation number of population. To have a long format data, we should change the wide format data by using "melt".
#
# Melt command refers to an action of taking wide format data and melts it into long format data, like a melting metal. (Reference: Sean C. Anderson, http://seananderson.ca/2013/10/19/reshape.html)
#
# According to Sean, there is also another command, which is "cast". In cast command, we cast long format data into wide format data.
#
# Wide format data? a summary of long format data! each category is grouped.

# %%
library(stringr)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Use stringr package to manipulate data and extract string (like adding or taking out header). Reference: introduction to stringr, CRAN.R-project.org. Basically, function of stringr package: to clean the data, simpifly string operations by eliminating data that you don't want, extract and replace substring from a character vector. Some commands used here, such as:
#
# str_sub
# str_subset
# str_locate
# str_replace
# word
# %>%

# %%
longpopulation %>% mutate(
    Year = str_sub(variable, start= -2),
)
# Out:
#       STNAME    CTYNAME            variable        value  Year
# 1     Alabama   Autauga County     POPESTIMATE2010  54742 10
# 2     Alabama   Baldwin County     POPESTIMATE2010 183199 10
# 3     Alabama   Barbour County     POPESTIMATE2010  27348 10
# 4     Alabama   Bibb County        POPESTIMATE2010  22861 10
# 5     Alabama   Blount County      POPESTIMATE2010  57376 10
# 6     Alabama   Bullock County     POPESTIMATE2010  10892 10
# 7     Alabama   Butler County      POPESTIMATE2010  20938 10
# 8     Alabama   Calhoun County     POPESTIMATE2010 118468 10
# 9     Alabama   Chambers County    POPESTIMATE2010  34101 10
# 10    Alabama   Cherokee County    POPESTIMATE2010  25977 10
# 11    Alabama   Chilton County     POPESTIMATE2010  43675 10
# 12    Alabama   Choctaw County     POPESTIMATE2010  13840 10
# 13    Alabama   Clarke County      POPESTIMATE2010  25762 10
# 14    Alabama   Clay County        POPESTIMATE2010  13882 10
# 15    Alabama   Cleburne County    POPESTIMATE2010  14975 10
# 16    Alabama   Coffee County      POPESTIMATE2010  50183 10
# 17    Alabama   Colbert County     POPESTIMATE2010  54521 10
# 18    Alabama   Conecuh County     POPESTIMATE2010  13209 10
# 19    Alabama   Coosa County       POPESTIMATE2010  11758 10
# 20    Alabama   Covington County   POPESTIMATE2010  37801 10
# 21    Alabama   Crenshaw County    POPESTIMATE2010  13857 10
# 22    Alabama   Cullman County     POPESTIMATE2010  80476 10
# 23    Alabama   Dale County        POPESTIMATE2010  50360 10
# 24    Alabama   Dallas County      POPESTIMATE2010  43820 10
# 25    Alabama   DeKalb County      POPESTIMATE2010  71143 10
# 26    Alabama   Elmore County      POPESTIMATE2010  79573 10
# 27    Alabama   Escambia County    POPESTIMATE2010  38314 10
# 28    Alabama   Etowah County      POPESTIMATE2010 104449 10
# 29    Alabama   Fayette County     POPESTIMATE2010  17231 10
# 30    Alabama   Franklin County    POPESTIMATE2010  31734 10
# ⋮     ⋮         ⋮                  ⋮               ⋮      ⋮
# 21965 Wisconsin Washburn County    POPESTIMATE2016  15648 16
# 21966 Wisconsin Washington County  POPESTIMATE2016 134296 16
# 21967 Wisconsin Waukesha County    POPESTIMATE2016 398424 16
# 21968 Wisconsin Waupaca County     POPESTIMATE2016  51533 16
# 21969 Wisconsin Waushara County    POPESTIMATE2016  24162 16
# 21970 Wisconsin Winnebago County   POPESTIMATE2016 169886 16
# 21971 Wisconsin Wood County        POPESTIMATE2016  73107 16
# 21972 Wyoming   Albany County      POPESTIMATE2016  38256 16
# 21973 Wyoming   Big Horn County    POPESTIMATE2016  12005 16
# 21974 Wyoming   Campbell County    POPESTIMATE2016  48803 16
# 21975 Wyoming   Carbon County      POPESTIMATE2016  15618 16
# 21976 Wyoming   Converse County    POPESTIMATE2016  14191 16
# 21977 Wyoming   Crook County       POPESTIMATE2016   7464 16
# 21978 Wyoming   Fremont County     POPESTIMATE2016  40242 16
# 21979 Wyoming   Goshen County      POPESTIMATE2016  13390 16
# 21980 Wyoming   Hot Springs County POPESTIMATE2016   4679 16
# 21981 Wyoming   Johnson County     POPESTIMATE2016   8486 16
# 21982 Wyoming   Laramie County     POPESTIMATE2016  98136 16
# 21983 Wyoming   Lincoln County     POPESTIMATE2016  19110 16
# 21984 Wyoming   Natrona County     POPESTIMATE2016  81039 16
# 21985 Wyoming   Niobrara County    POPESTIMATE2016   2480 16
# 21986 Wyoming   Park County        POPESTIMATE2016  29353 16
# 21987 Wyoming   Platte County      POPESTIMATE2016   8680 16
# 21988 Wyoming   Sheridan County    POPESTIMATE2016  30200 16
# 21989 Wyoming   Sublette County    POPESTIMATE2016   9769 16
# 21990 Wyoming   Sweetwater County  POPESTIMATE2016  44165 16
# 21991 Wyoming   Teton County       POPESTIMATE2016  23191 16
# 21992 Wyoming   Uinta County       POPESTIMATE2016  20773 16
# 21993 Wyoming   Washakie County    POPESTIMATE2016   8235 16
# 21994 Wyoming   Weston County      POPESTIMATE2016   7236 16

# %% [markdown]
# we want to add year as variable. so we use the command: Year = str_sub(variable, start= -2).
# str_sub refers to an action to extract and replace substring. Meanwhile dplyr mutate means adding new variable by perserving the existing ones, as in year. Reference: Statistical tools for high-throughput data analysis (sthda.com)

# %%
longpopulation %>% mutate(
    Year = 2000 + as.integer(str_sub(variable, start= -2)),
)
# Out:
#       STNAME    CTYNAME            variable        value  Year
# 1     Alabama   Autauga County     POPESTIMATE2010  54742 2010
# 2     Alabama   Baldwin County     POPESTIMATE2010 183199 2010
# 3     Alabama   Barbour County     POPESTIMATE2010  27348 2010
# 4     Alabama   Bibb County        POPESTIMATE2010  22861 2010
# 5     Alabama   Blount County      POPESTIMATE2010  57376 2010
# 6     Alabama   Bullock County     POPESTIMATE2010  10892 2010
# 7     Alabama   Butler County      POPESTIMATE2010  20938 2010
# 8     Alabama   Calhoun County     POPESTIMATE2010 118468 2010
# 9     Alabama   Chambers County    POPESTIMATE2010  34101 2010
# 10    Alabama   Cherokee County    POPESTIMATE2010  25977 2010
# 11    Alabama   Chilton County     POPESTIMATE2010  43675 2010
# 12    Alabama   Choctaw County     POPESTIMATE2010  13840 2010
# 13    Alabama   Clarke County      POPESTIMATE2010  25762 2010
# 14    Alabama   Clay County        POPESTIMATE2010  13882 2010
# 15    Alabama   Cleburne County    POPESTIMATE2010  14975 2010
# 16    Alabama   Coffee County      POPESTIMATE2010  50183 2010
# 17    Alabama   Colbert County     POPESTIMATE2010  54521 2010
# 18    Alabama   Conecuh County     POPESTIMATE2010  13209 2010
# 19    Alabama   Coosa County       POPESTIMATE2010  11758 2010
# 20    Alabama   Covington County   POPESTIMATE2010  37801 2010
# 21    Alabama   Crenshaw County    POPESTIMATE2010  13857 2010
# 22    Alabama   Cullman County     POPESTIMATE2010  80476 2010
# 23    Alabama   Dale County        POPESTIMATE2010  50360 2010
# 24    Alabama   Dallas County      POPESTIMATE2010  43820 2010
# 25    Alabama   DeKalb County      POPESTIMATE2010  71143 2010
# 26    Alabama   Elmore County      POPESTIMATE2010  79573 2010
# 27    Alabama   Escambia County    POPESTIMATE2010  38314 2010
# 28    Alabama   Etowah County      POPESTIMATE2010 104449 2010
# 29    Alabama   Fayette County     POPESTIMATE2010  17231 2010
# 30    Alabama   Franklin County    POPESTIMATE2010  31734 2010
# ⋮     ⋮         ⋮                  ⋮               ⋮      ⋮
# 21965 Wisconsin Washburn County    POPESTIMATE2016  15648 2016
# 21966 Wisconsin Washington County  POPESTIMATE2016 134296 2016
# 21967 Wisconsin Waukesha County    POPESTIMATE2016 398424 2016
# 21968 Wisconsin Waupaca County     POPESTIMATE2016  51533 2016
# 21969 Wisconsin Waushara County    POPESTIMATE2016  24162 2016
# 21970 Wisconsin Winnebago County   POPESTIMATE2016 169886 2016
# 21971 Wisconsin Wood County        POPESTIMATE2016  73107 2016
# 21972 Wyoming   Albany County      POPESTIMATE2016  38256 2016
# 21973 Wyoming   Big Horn County    POPESTIMATE2016  12005 2016
# 21974 Wyoming   Campbell County    POPESTIMATE2016  48803 2016
# 21975 Wyoming   Carbon County      POPESTIMATE2016  15618 2016
# 21976 Wyoming   Converse County    POPESTIMATE2016  14191 2016
# 21977 Wyoming   Crook County       POPESTIMATE2016   7464 2016
# 21978 Wyoming   Fremont County     POPESTIMATE2016  40242 2016
# 21979 Wyoming   Goshen County      POPESTIMATE2016  13390 2016
# 21980 Wyoming   Hot Springs County POPESTIMATE2016   4679 2016
# 21981 Wyoming   Johnson County     POPESTIMATE2016   8486 2016
# 21982 Wyoming   Laramie County     POPESTIMATE2016  98136 2016
# 21983 Wyoming   Lincoln County     POPESTIMATE2016  19110 2016
# 21984 Wyoming   Natrona County     POPESTIMATE2016  81039 2016
# 21985 Wyoming   Niobrara County    POPESTIMATE2016   2480 2016
# 21986 Wyoming   Park County        POPESTIMATE2016  29353 2016
# 21987 Wyoming   Platte County      POPESTIMATE2016   8680 2016
# 21988 Wyoming   Sheridan County    POPESTIMATE2016  30200 2016
# 21989 Wyoming   Sublette County    POPESTIMATE2016   9769 2016
# 21990 Wyoming   Sweetwater County  POPESTIMATE2016  44165 2016
# 21991 Wyoming   Teton County       POPESTIMATE2016  23191 2016
# 21992 Wyoming   Uinta County       POPESTIMATE2016  20773 2016
# 21993 Wyoming   Washakie County    POPESTIMATE2016   8235 2016
# 21994 Wyoming   Weston County      POPESTIMATE2016   7236 2016

# %% [markdown]
# You want to have 2010 and not 10 for "Year". Therefore, we use this command: Year = 2000 + as.integer(str_sub(variable, start= -2)),
# ), which can be read as you add 2000+ 2 last number as integer. E.g. 2000 + 16 (two last numbers in "Year" which become integer).

# %%
longpopulation %>% mutate(
    Year = 2000 + as.integer(str_sub(variable, start= -2)),
) %>% select (-c(variable)) %>% rename(Estimate=value)
# Out:
#       STNAME    CTYNAME            Estimate Year
# 1     Alabama   Autauga County      54742   2010
# 2     Alabama   Baldwin County     183199   2010
# 3     Alabama   Barbour County      27348   2010
# 4     Alabama   Bibb County         22861   2010
# 5     Alabama   Blount County       57376   2010
# 6     Alabama   Bullock County      10892   2010
# 7     Alabama   Butler County       20938   2010
# 8     Alabama   Calhoun County     118468   2010
# 9     Alabama   Chambers County     34101   2010
# 10    Alabama   Cherokee County     25977   2010
# 11    Alabama   Chilton County      43675   2010
# 12    Alabama   Choctaw County      13840   2010
# 13    Alabama   Clarke County       25762   2010
# 14    Alabama   Clay County         13882   2010
# 15    Alabama   Cleburne County     14975   2010
# 16    Alabama   Coffee County       50183   2010
# 17    Alabama   Colbert County      54521   2010
# 18    Alabama   Conecuh County      13209   2010
# 19    Alabama   Coosa County        11758   2010
# 20    Alabama   Covington County    37801   2010
# 21    Alabama   Crenshaw County     13857   2010
# 22    Alabama   Cullman County      80476   2010
# 23    Alabama   Dale County         50360   2010
# 24    Alabama   Dallas County       43820   2010
# 25    Alabama   DeKalb County       71143   2010
# 26    Alabama   Elmore County       79573   2010
# 27    Alabama   Escambia County     38314   2010
# 28    Alabama   Etowah County      104449   2010
# 29    Alabama   Fayette County      17231   2010
# 30    Alabama   Franklin County     31734   2010
# ⋮     ⋮         ⋮                  ⋮        ⋮
# 21965 Wisconsin Washburn County     15648   2016
# 21966 Wisconsin Washington County  134296   2016
# 21967 Wisconsin Waukesha County    398424   2016
# 21968 Wisconsin Waupaca County      51533   2016
# 21969 Wisconsin Waushara County     24162   2016
# 21970 Wisconsin Winnebago County   169886   2016
# 21971 Wisconsin Wood County         73107   2016
# 21972 Wyoming   Albany County       38256   2016
# 21973 Wyoming   Big Horn County     12005   2016
# 21974 Wyoming   Campbell County     48803   2016
# 21975 Wyoming   Carbon County       15618   2016
# 21976 Wyoming   Converse County     14191   2016
# 21977 Wyoming   Crook County         7464   2016
# 21978 Wyoming   Fremont County      40242   2016
# 21979 Wyoming   Goshen County       13390   2016
# 21980 Wyoming   Hot Springs County   4679   2016
# 21981 Wyoming   Johnson County       8486   2016
# 21982 Wyoming   Laramie County      98136   2016
# 21983 Wyoming   Lincoln County      19110   2016
# 21984 Wyoming   Natrona County      81039   2016
# 21985 Wyoming   Niobrara County      2480   2016
# 21986 Wyoming   Park County         29353   2016
# 21987 Wyoming   Platte County        8680   2016
# 21988 Wyoming   Sheridan County     30200   2016
# 21989 Wyoming   Sublette County      9769   2016
# 21990 Wyoming   Sweetwater County   44165   2016
# 21991 Wyoming   Teton County        23191   2016
# 21992 Wyoming   Uinta County        20773   2016
# 21993 Wyoming   Washakie County      8235   2016
# 21994 Wyoming   Weston County        7236   2016

# %% [markdown]
# REMOVE UNWANTED VARIABLE! Make it short and simple. And eliminate the "variable" and rename "value" into another name as "estimate". %>% select (-c(variable)) %>% rename(Estimate=value). At the end, you will have a dataset consists of State name, County name, Estimate number (value) and Year.
